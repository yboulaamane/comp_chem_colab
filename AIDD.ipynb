# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# !conda --version
# !conda config --add channels conda-forge
# !conda install -c rdkit rdkit -y
# !conda install molvs -y
# !conda install -c sepandhaghighi pycm -y
# !conda install -c conda-forge imbalanced-learn -y
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:33
# 🔁 Restarting kernel...
# conda 4.9.2
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     cairo-1.16.0               |       hf32fb01_1         1.0 MB
#     certifi-2022.6.15          |   py37h89c1867_0         155 KB  conda-forge
#     conda-4.13.0               |   py37h89c1867_1         989 KB  conda-forge
#     fontconfig-2.13.1          |       h6c09931_0         250 KB
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     glib-2.69.1                |       h4ff587b_1         1.7 MB
#     icu-58.2                   |    hf484d3e_1000        22.6 MB  conda-forge
#     jpeg-9e                    |       h7f8727e_0         240 KB
#     libblas-3.9.0              |11_linux64_openblas          12 KB  conda-forge
#     libboost-1.73.0            |      h3ff78a5_11        13.9 MB
#     libcblas-3.9.0             |11_linux64_openblas          11 KB  conda-forge
#     libgfortran-ng-12.1.0      |      h69a702a_16          23 KB  conda-forge
#     libgfortran5-12.1.0        |      hdcd56e2_16         1.8 MB  conda-forge
#     liblapack-3.9.0            |11_linux64_openblas          11 KB  conda-forge
#     libopenblas-0.3.17         |pthreads_h8fe5266_1         9.2 MB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libtiff-4.0.10             |    hc3755c2_1005         602 KB  conda-forge
#     libuuid-1.0.3              |       h7f8727e_2          17 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxml2-2.9.12             |       h03d6c58_0         1.2 MB
#     numpy-1.20.3               |   py37h038b26d_1         5.7 MB  conda-forge
#     olefile-0.46               |     pyh9f0ad1d_1          32 KB  conda-forge
#     pandas-1.2.3               |   py37hdc94413_0        11.8 MB  conda-forge
#     pcre-8.45                  |       h9c3ff4c_0         253 KB  conda-forge
#     pillow-6.2.1               |   py37h6b7be26_0         637 KB  conda-forge
#     pixman-0.40.0              |       h36c2ea0_0         627 KB  conda-forge
#     py-boost-1.73.0            |  py37ha9443f7_11         204 KB
#     python-dateutil-2.8.2      |     pyhd8ed1ab_0         240 KB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     pytz-2022.1                |     pyhd8ed1ab_0         242 KB  conda-forge
#     rdkit-2020.09.1.0          |   py37hd50e099_1        25.8 MB  rdkit
#     ------------------------------------------------------------
#                                            Total:       100.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              pkgs/main/linux-64::cairo-1.16.0-hf32fb01_1
#   fontconfig         pkgs/main/linux-64::fontconfig-2.13.1-h6c09931_0
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   glib               pkgs/main/linux-64::glib-2.69.1-h4ff587b_1
#   jpeg               pkgs/main/linux-64::jpeg-9e-h7f8727e_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-11_linux64_openblas
#   libboost           pkgs/main/linux-64::libboost-1.73.0-h3ff78a5_11
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-11_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.1.0-h69a702a_16
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.1.0-hdcd56e2_16
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-11_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.17-pthreads_h8fe5266_1
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libtiff            conda-forge/linux-64::libtiff-4.0.10-hc3755c2_1005
#   libuuid            pkgs/main/linux-64::libuuid-1.0.3-h7f8727e_2
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   numpy              conda-forge/linux-64::numpy-1.20.3-py37h038b26d_1
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   pandas             conda-forge/linux-64::pandas-1.2.3-py37hdc94413_0
#   pcre               conda-forge/linux-64::pcre-8.45-h9c3ff4c_0
#   pillow             conda-forge/linux-64::pillow-6.2.1-py37h6b7be26_0
#   pixman             conda-forge/linux-64::pixman-0.40.0-h36c2ea0_0
#   py-boost           pkgs/main/linux-64::py-boost-1.73.0-py37ha9443f7_11
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2022.1-pyhd8ed1ab_0
#   rdkit              rdkit/linux-64::rdkit-2020.09.1.0-py37hd50e099_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.12.5-ha878542_0 --> 2022.6.15-ha878542_0
#   certifi                          2020.12.5-py37h89c1867_1 --> 2022.6.15-py37h89c1867_0
#   conda                                4.9.2-py37h89c1867_0 --> 4.13.0-py37h89c1867_1
#   libxml2            conda-forge::libxml2-2.9.10-h72842e0_3 --> pkgs/main::libxml2-2.9.12-h03d6c58_0
#   python_abi                                    3.7-1_cp37m --> 3.7-2_cp37m
#
# The following packages will be DOWNGRADED:
#
#   icu                                       68.1-h58526e2_0 --> 58.2-hf484d3e_1000
#
#
#
# Downloading and Extracting Packages
# olefile-0.46         | 32 KB     | : 100% 1.0/1 [00:00<00:00,  8.06it/s]
# fontconfig-2.13.1    | 250 KB    | : 100% 1.0/1 [00:00<00:00,  6.25it/s]
# libcblas-3.9.0       | 11 KB     | : 100% 1.0/1 [00:00<00:00, 20.77it/s]
# certifi-2022.6.15    | 155 KB    | : 100% 1.0/1 [00:00<00:00, 11.81it/s]
# pandas-1.2.3         | 11.8 MB   | : 100% 1.0/1 [00:05<00:00,  6.00s/it]
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 22.70it/s]
# libboost-1.73.0      | 13.9 MB   | : 100% 1.0/1 [00:02<00:00,  2.09s/it]
# libopenblas-0.3.17   | 9.2 MB    | : 100% 1.0/1 [00:02<00:00,  2.25s/it]
# py-boost-1.73.0      | 204 KB    | : 100% 1.0/1 [00:00<00:00, 11.84it/s]
# libxml2-2.9.12       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  7.14it/s]
# pixman-0.40.0        | 627 KB    | : 100% 1.0/1 [00:00<00:00,  6.10it/s]
# libuuid-1.0.3        | 17 KB     | : 100% 1.0/1 [00:00<00:00, 14.58it/s]
# libgfortran5-12.1.0  | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.33it/s]
# pillow-6.2.1         | 637 KB    | : 100% 1.0/1 [00:00<00:00,  3.54it/s]
# rdkit-2020.09.1.0    | 25.8 MB   | : 100% 1.0/1 [00:06<00:00,  6.28s/it]
# liblapack-3.9.0      | 11 KB     | : 100% 1.0/1 [00:00<00:00, 23.71it/s]
# ca-certificates-2022 | 149 KB    | : 100% 1.0/1 [00:00<00:00, 15.23it/s]
# libxcb-1.15          | 505 KB    | : 100% 1.0/1 [00:00<00:00,  8.94it/s]
# libpng-1.6.37        | 306 KB    | : 100% 1.0/1 [00:00<00:00,  8.52it/s]
# cairo-1.16.0         | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  8.29it/s]
# pcre-8.45            | 253 KB    | : 100% 1.0/1 [00:00<00:00,  9.93it/s]
# libgfortran-ng-12.1. | 23 KB     | : 100% 1.0/1 [00:00<00:00, 23.49it/s]
# glib-2.69.1          | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  6.82it/s]
# jpeg-9e              | 240 KB    | : 100% 1.0/1 [00:00<00:00, 11.82it/s]
# libblas-3.9.0        | 12 KB     | : 100% 1.0/1 [00:00<00:00, 24.62it/s]
# freetype-2.10.4      | 890 KB    | : 100% 1.0/1 [00:00<00:00,  3.99it/s]
# numpy-1.20.3         | 5.7 MB    | : 100% 1.0/1 [00:02<00:00,  2.24s/it]
# icu-58.2             | 22.6 MB   | : 100% 1.0/1 [00:04<00:00,  4.89s/it]
# python-dateutil-2.8. | 240 KB    | : 100% 1.0/1 [00:00<00:00, 13.65it/s]
# pytz-2022.1          | 242 KB    | : 100% 1.0/1 [00:00<00:00,  6.90it/s]
# libtiff-4.0.10       | 602 KB    | : 100% 1.0/1 [00:00<00:00,  4.74it/s]
# conda-4.13.0         | 989 KB    | : 100% 1.0/1 [00:00<00:00,  2.71it/s]
# done
# done
# done
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - molvs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     molvs-0.1.1                |             py_0          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          25 KB
#
# The following NEW packages will be INSTALLED:
#
#   molvs              conda-forge/noarch::molvs-0.1.1-py_0
#
#
#
# Downloading and Extracting Packages
# molvs-0.1.1          | 25 KB     | : 100% 1.0/1 [00:00<00:00,  6.85it/s]
# done
# done
# done
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pycm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     art-5.7                    |             py_0         752 KB  sepandhaghighi
#     pycm-3.5                   |             py_0         321 KB  sepandhaghighi
#     ------------------------------------------------------------
#                                            Total:         1.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   art                sepandhaghighi/noarch::art-5.7-py_0
#   pycm               sepandhaghighi/noarch::pycm-3.5-py_0
#
#
#
# Downloading and Extracting Packages
# art-5.7              | 752 KB    | : 100% 1.0/1 [00:00<00:00,  1.48it/s]
# pycm-3.5             | 321 KB    | : 100% 1.0/1 [00:00<00:00,  2.75it/s]
# done
# done
# done
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - imbalanced-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     imbalanced-learn-0.7.0     |             py_1          97 KB  conda-forge
#     joblib-1.1.0               |     pyhd8ed1ab_0         210 KB  conda-forge
#     scikit-learn-0.23.2        |   py37hddcf8d6_3         6.8 MB  conda-forge
#     scipy-1.5.3                |   py37h14a347d_0        19.1 MB  conda-forge
#     threadpoolctl-3.1.0        |     pyh8a188c0_0          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        26.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   imbalanced-learn   conda-forge/noarch::imbalanced-learn-0.7.0-py_1
#   joblib             conda-forge/noarch::joblib-1.1.0-pyhd8ed1ab_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-0.23.2-py37hddcf8d6_3
#   scipy              conda-forge/linux-64::scipy-1.5.3-py37h14a347d_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.1.0-pyh8a188c0_0
#
#
#
# Downloading and Extracting Packages
# scikit-learn-0.23.2  | 6.8 MB    | : 100% 1.0/1 [00:02<00:00,  2.68s/it]
# threadpoolctl-3.1.0  | 18 KB     | : 100% 1.0/1 [00:00<00:00, 17.07it/s]
# imbalanced-learn-0.7 | 97 KB     | : 100% 1.0/1 [00:00<00:00,  8.84it/s]
# scipy-1.5.3          | 19.1 MB   | : 100% 1.0/1 [00:04<00:00,  4.41s/it]
# joblib-1.1.0         | 210 KB    | : 100% 1.0/1 [00:00<00:00,  6.34it/s]
# done
# done
# done
